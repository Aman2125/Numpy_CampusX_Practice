# %% [markdown]
# <a href="https://colab.research.google.com/github/Aman2125/DataScience_CampusX_Practice/blob/main/7)aman_DataFrameMethods.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#value_counts
#sort_values
#rank
#sort index
#rename index -> rename
#reset index
#unique & nunique
#isnull/notnull/hasnans
#dropna
#fillna
#drop_duplicates
#drop
#apply
#isin
#corr
#nlargest -> nsmallest
#insert
#copy

# %%
import numpy as np
import pandas as pd

# %%
#value_counts (Applicable on Series and DataFrame)
marks=pd.DataFrame([
    [100,80,10],
    [90,70,7],
    [120,100,14],
    [80,60,23],
    [80,60,23]
],columns = ['iq','marks','package'])
marks
# Out:
#     iq  marks  package
# 0  100     80       10
# 1   90     70        7
# 2  120    100       14
# 3   80     60       23
# 4   80     60       23

# %%
marks.value_counts() #count the frequncy of complete row
# Out:
# iq   marks  package
# 80   60     23         2
# 90   70     7          1
# 100  80     10         1
# 120  100    14         1
# Name: count, dtype: int64

# %%
ipl = pd.read_csv('/content/ipl-matches.csv')
ipl
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %%
#find which player has won most potm -> in finals and qualifiers
ipl[~ipl['MatchNumber'].str.isdigit()]['Player_of_Match'].value_counts()
# Out:
# Player_of_Match
# F du Plessis         3
# SK Raina             3
# KA Pollard           3
# JJ Bumrah            2
# AB de Villiers       2
# MK Pandey            2
# M Vijay              2
# A Kumble             2
# YK Pathan            2
# SR Watson            2
# HH Pandya            1
# RM Patidar           1
# JC Buttler           1
# RR Pant              1
# KS Williamson        1
# MP Stoinis           1
# TA Boult             1
# SP Narine            1
# RD Gaikwad           1
# VR Iyer              1
# DA Miller            1
# Washington Sundar    1
# NM Coulter-Nile      1
# KV Sharma            1
# BCJ Cutting          1
# KH Pandya            1
# SA Yadav             1
# Rashid Khan          1
# AD Russell           1
# RG Sharma            1
# A Nehra              1
# DA Warner            1
# MC Henriques         1
# Harbhajan Singh      1
# BJ Hodge             1
# UT Yadav             1
# V Sehwag             1
# MS Bisla             1
# MEK Hussey           1
# ...

# %%
# Toss decision plot
ipl['TossDecision'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
#how many matches each team has played
(ipl['Team1'].value_counts() + ipl['Team2'].value_counts()).sort_values(ascending=False)
# Out:
# Mumbai Indians                 231
# Royal Challengers Bangalore    226
# Kolkata Knight Riders          223
# Chennai Super Kings            208
# Rajasthan Royals               192
# Kings XI Punjab                190
# Delhi Daredevils               161
# Sunrisers Hyderabad            152
# Deccan Chargers                 75
# Delhi Capitals                  63
# Pune Warriors                   46
# Gujarat Lions                   30
# Punjab Kings                    28
# Gujarat Titans                  16
# Rising Pune Supergiant          16
# Lucknow Super Giants            15
# Kochi Tuskers Kerala            14
# Rising Pune Supergiants         14
# Name: count, dtype: int64

# %%
# sort_values(series and dataframe) -> ascending ->na_position -> inplace -> multiple cols

# %%
x = pd.Series([12,3,53,1])
x
# Out:
# 0    12
# 1     3
# 2    53
# 3     1
# dtype: int64

# %%
# sort on series
x.sort_values(ascending=False)
# Out:
# 2    53
# 0    12
# 1     3
# 3     1
# dtype: int64

# %%
#sort in dataframe
movies = pd.read_csv('movies.csv')
movies.head(3)
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1        https://en.wikipedia.org/wiki/Battalion_609
# 2  https://en.wikipedia.org/wiki/The_Accidental_P...
#
#                          title_y                 original_title  is_adult  \
# 0       Uri: The Surgical Strike       Uri: The Surgical Strike         0
# 1                  Battalion 609                  Battalion 609         0
# 2  The Accidental Prime Minister  The Accidental Prime Minister         0
#
# ...

# %%
movies.sort_values(['title_x'] , ascending=False).head(2) #sorting one single col
# Out:
#                     title_x    imdb_id  \
# 1623               Zubeidaa  tt0255713
# 939   Zor Lagaa Ke...Haiya!  tt1479857
#
#                                             poster_path  \
# 1623  https://upload.wikimedia.org/wikipedia/en/thum...
# 939   https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                               wiki_link  \
# 1623             https://en.wikipedia.org/wiki/Zubeidaa
# 939   https://en.wikipedia.org/wiki/Zor_Lagaa_Ke...H...
#
#                      title_y          original_title  is_adult  \
# 1623                Zubeidaa                Zubeidaa         0
# 939   Zor Lagaa Ke... Haiya!  Zor Lagaa Ke... Haiya!         0
#
#       year_of_release runtime                   genres  imdb_rating  \
# 1623             2001     153  Biography|Drama|History          6.2
# 939              2009      \N      Comedy|Drama|Family          6.4
#
#       imdb_votes                                              story  \
# ...

# %%
students = pd.DataFrame(
    {
        'name':['nitish','ankit','rupesh',np.nan,'mrityunjay',np.nan,'rishabh',np.nan,'aditya',np.nan],
        'college':['bit','iit','vit',np.nan,np.nan,'vlsi','ssit',np.nan,np.nan,'git'],
        'branch':['eee','it','cse',np.nan,'me','ce','civ','cse','bio',np.nan],
        'cgpa':[6.66,8.25,6.41,np.nan,5.6,9.0,7.4,10,7.4,np.nan],
        'package':[4,5,6,np.nan,6,7,8,9,np.nan,np.nan]

    }
)

students
# Out:
#          name college branch   cgpa  package
# 0      nitish     bit    eee   6.66      4.0
# 1       ankit     iit     it   8.25      5.0
# 2      rupesh     vit    cse   6.41      6.0
# 3         NaN     NaN    NaN    NaN      NaN
# 4  mrityunjay     NaN     me   5.60      6.0
# 5         NaN    vlsi     ce   9.00      7.0
# 6     rishabh    ssit    civ   7.40      8.0
# 7         NaN     NaN    cse  10.00      9.0
# 8      aditya     NaN    bio   7.40      NaN
# 9         NaN     git    NaN    NaN      NaN

# %%
#applyig sorting on nan values
students.sort_values(['name'] , na_position='first')
#na_position =first for making the NaN values on top as by default while sorting all NaN vales moves to the end
# Out:
#          name college branch   cgpa  package
# 3         NaN     NaN    NaN    NaN      NaN
# 5         NaN    vlsi     ce   9.00      7.0
# 7         NaN     NaN    cse  10.00      9.0
# 9         NaN     git    NaN    NaN      NaN
# 8      aditya     NaN    bio   7.40      NaN
# 1       ankit     iit     it   8.25      5.0
# 4  mrityunjay     NaN     me   5.60      6.0
# 0      nitish     bit    eee   6.66      4.0
# 6     rishabh    ssit    civ   7.40      8.0
# 2      rupesh     vit    cse   6.41      6.0

# %%
#sorting on multiple cols
movies.head(2)
# Out:
#                     title_x    imdb_id  \
# 0  Uri: The Surgical Strike  tt8291224
# 1             Battalion 609  tt9472208
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1        https://en.wikipedia.org/wiki/Battalion_609
#
#                     title_y            original_title  is_adult  \
# 0  Uri: The Surgical Strike  Uri: The Surgical Strike         0
# 1             Battalion 609             Battalion 609         0
#
#    year_of_release runtime            genres  imdb_rating  imdb_votes  \
# 0             2019     138  Action|Drama|War          8.4       35112
# 1             2019     131               War          4.1          73
#
#                                                story  \
# ...

# %%
#sort on year of relaease and then inside of that sort alphabetically
movies.sort_values(['year_of_release','title_x']).head(4)
# Out:
#                                title_x    imdb_id  \
# 1575                       Aalavandhan  tt0294264
# 1576  Aamdani Atthanni Kharcha Rupaiya  tt0305173
# 1577                Aashiq (2001 film)  tt0273406
# 1579               Ajnabee (2001 film)  tt0278291
#
#                                             poster_path  \
# 1575  https://upload.wikimedia.org/wikipedia/en/thum...
# 1576  https://upload.wikimedia.org/wikipedia/en/thum...
# 1577  https://upload.wikimedia.org/wikipedia/en/c/c6...
# 1579  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                               wiki_link  \
# 1575          https://en.wikipedia.org/wiki/Aalavandhan
# 1576  https://en.wikipedia.org/wiki/Aamdani_Atthanni...
# 1577   https://en.wikipedia.org/wiki/Aashiq_(2001_film)
# 1579  https://en.wikipedia.org/wiki/Ajnabee_(2001_film)
#
#                                title_y                    original_title  \
# ...

# %%
#rank(applicable only on Series)
batsman = pd.read_csv('batsman_runs_ipl.csv')
batsman.sample(5)
# Out:
#            batter  batsman_run
# 572     V Shankar          731
# 30      AC Thomas           20
# 163      DT Patil           13
# 262  KL Nagarkoti           22
# 273     KV Sharma          317

# %%
batsman['batting_rank'] = batsman['batsman_run'].rank(ascending=False) #ranking is done by ascending order by default
batsman.sort_values('batting_rank').head(5)
# Out:
#         batter  batsman_run  batting_rank
# 569    V Kohli         6634           1.0
# 462   S Dhawan         6244           2.0
# 130  DA Warner         5883           3.0
# 430  RG Sharma         5881           4.0
# 493   SK Raina         5536           5.0

# %%
# sort_index (series and dataframe)

# %%
marks = {
    'maths':67,
    'english':57,
    'science':89,
    'hindi':100
}

marks_series = pd.Series(marks)
marks_series
# Out:
# maths       67
# english     57
# science     89
# hindi      100
# dtype: int64

# %%
marks_series.sort_index() #sorting in series on basis of index
# Out:
# english     57
# hindi      100
# maths       67
# science     89
# dtype: int64

# %%
#in dataframe
movies.sort_index(ascending=False).head(3)
# Out:
#               title_x     imdb_id  \
# 1628         Humsafar   tt2403201
# 1627            Daaka  tt10833860
# 1626  Sabse Bada Sukh   tt0069204
#
#                                             poster_path  \
# 1628  https://upload.wikimedia.org/wikipedia/en/thum...
# 1627  https://upload.wikimedia.org/wikipedia/en/thum...
# 1626                                                NaN
#
#                                           wiki_link          title_y  \
# 1628         https://en.wikipedia.org/wiki/Humsafar         Humsafar
# 1627            https://en.wikipedia.org/wiki/Daaka            Daaka
# 1626  https://en.wikipedia.org/wiki/Sabse_Bada_Sukh  Sabse Bada Sukh
#
#        original_title  is_adult  year_of_release runtime         genres  \
# 1628         Humsafar         0             2011      35  Drama|Romance
# 1627            Daaka         0             2019     136         Action
# 1626  Sabse Bada Sukh         0             2018      \N   Comedy|Drama
#
# ...

# %%
# set_index(dataframe) -> inplace
batsman.set_index('batter',inplace=True ) #making batter name as index in place of 0,1,2,..
batsman
# Out:
#                 batsman_run  batting_rank
# batter
# A Ashish Reddy          280         166.5
# A Badoni                161         226.0
# A Chandila                4         535.0
# A Chopra                 53         329.0
# A Choudhary              25         402.5
# ...                     ...           ...
# Yash Dayal                0         594.0
# Yashpal Singh            47         343.0
# Younis Khan               3         547.5
# Yuvraj Singh           2754          27.0
# Z Khan                  117         256.0
#
# [605 rows x 2 columns]

# %%
# reset_index (series and dataframe) -> drop parameter
batsman.reset_index().head(5)
# Out:
#            batter  batsman_run  batting_rank
# 0  A Ashish Reddy          280         166.5
# 1        A Badoni          161         226.0
# 2      A Chandila            4         535.0
# 3        A Chopra           53         329.0
# 4     A Choudhary           25         402.5

# %%
#how to replace existing index without lossing
#que make batsman_run as index col inplace of batter
batsman.reset_index().set_index('batsman_run')
# Out:
#                      batter  batting_rank
# batsman_run
# 280          A Ashish Reddy         166.5
# 161                A Badoni         226.0
# 4                A Chandila         535.0
# 53                 A Chopra         329.0
# 25              A Choudhary         402.5
# ...                     ...           ...
# 0                Yash Dayal         594.0
# 47            Yashpal Singh         343.0
# 3               Younis Khan         547.5
# 2754           Yuvraj Singh          27.0
# 117                  Z Khan         256.0
#
# [605 rows x 2 columns]

# %%
#series to dataframe using reset_index
marks_series.reset_index() #series is converted in to dataframe
# Out:
#      index    0
# 0    maths   67
# 1  english   57
# 2  science   89
# 3    hindi  100

# %%
#rename(dataframe) -> index
movies.set_index('title_x',inplace=True)
movies.head()
# Out:
#                                         imdb_id  \
# title_x
# Uri: The Surgical Strike              tt8291224
# Battalion 609                         tt9472208
# The Accidental Prime Minister (film)  tt6986710
# Why Cheat India                       tt8108208
# Evening Shadows                       tt6028796
#
#                                                                             poster_path  \
# title_x
# Uri: The Surgical Strike              https://upload.wikimedia.org/wikipedia/en/thum...
# Battalion 609                                                                       NaN
# The Accidental Prime Minister (film)  https://upload.wikimedia.org/wikipedia/en/thum...
# Why Cheat India                       https://upload.wikimedia.org/wikipedia/en/thum...
# Evening Shadows                                                                     NaN
#
#                                                                               wiki_link  \
# title_x
# ...

# %%
movies.rename(columns={'imdb_id' : 'imdb' , 'poster_path' : 'link'} , inplace=True) #col rename

# %%
movies.rename(index={'Uri: The Surgical Strike':'Uri' ,'Battalion 609':'B' }).head(2) #index rename
# Out:
#               imdb                                               link  \
# title_x
# Uri      tt8291224  https://upload.wikimedia.org/wikipedia/en/thum...
# B        tt9472208                                                NaN
#
#                                                  wiki_link  \
# title_x
# Uri      https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# B              https://en.wikipedia.org/wiki/Battalion_609
#
#                           title_y            original_title  is_adult  \
# title_x
# Uri      Uri: The Surgical Strike  Uri: The Surgical Strike         0
# B                   Battalion 609             Battalion 609         0
#
#          year_of_release runtime            genres  imdb_rating  imdb_votes  \
# title_x
# Uri                 2019     138  Action|Drama|War          8.4       35112
# B                   2019     131               War          4.1          73
#
#                                                      story  \
# title_x
# ...

# %%
#unique(Series)
temp = pd.Series([1,1,2,3,3,4,4,4,5,5,5,6,np.nan,np.nan])
print(temp)
temp.unique()
# Out:
# 0     1.0
# 1     1.0
# 2     2.0
# 3     3.0
# 4     3.0
# 5     4.0
# 6     4.0
# 7     4.0
# 8     5.0
# 9     5.0
# 10    5.0
# 11    6.0
# 12    NaN
# 13    NaN
# dtype: float64
# array([ 1.,  2.,  3.,  4.,  5.,  6., nan])

# %%
ipl['Season'].unique()
# Out:
# array(['2022', '2021', '2020/21', '2019', '2018', '2017', '2016', '2015',
#        '2014', '2013', '2012', '2011', '2009/10', '2009', '2007/08'],
#       dtype=object)

# %%
# nunique(series + dataframe) -> doesnot count nan -> dropna prameter
ipl['Season'].nunique() #finds the count
# Out:
# 15

# %%
len(temp.unique())
# Out:
# 7

# %%
# isnull(series + dataframe)
students['name'][students['name'].isnull()]
# Out:
# 3    NaN
# 5    NaN
# 7    NaN
# 9    NaN
# Name: name, dtype: object

# %%
# notnull(series + dataframe)
students['name'][students['name'].notnull()] #opposite of isnull
# Out:
# 0        nitish
# 1         ankit
# 2        rupesh
# 4    mrityunjay
# 6       rishabh
# 8        aditya
# Name: name, dtype: object

# %%
# hasnans(series)
students['name'].hasnans #only tell has nan value or not
# Out:
# True

# %%
# isnull(series + dataframe)
students
# Out:
#          name college branch   cgpa  package
# 0      nitish     bit    eee   6.66      4.0
# 1       ankit     iit     it   8.25      5.0
# 2      rupesh     vit    cse   6.41      6.0
# 3         NaN     NaN    NaN    NaN      NaN
# 4  mrityunjay     NaN     me   5.60      6.0
# 5         NaN    vlsi     ce   9.00      7.0
# 6     rishabh    ssit    civ   7.40      8.0
# 7         NaN     NaN    cse  10.00      9.0
# 8      aditya     NaN    bio   7.40      NaN
# 9         NaN     git    NaN    NaN      NaN

# %%
#applying on dataframe
students.isnull() #asks each value
# Out:
#     name  college  branch   cgpa  package
# 0  False    False   False  False    False
# 1  False    False   False  False    False
# 2  False    False   False  False    False
# 3   True     True    True   True     True
# 4  False     True   False  False    False
# 5   True    False   False  False    False
# 6  False    False   False  False    False
# 7   True     True   False  False    False
# 8  False     True   False  False     True
# 9   True    False    True   True     True

# %%
students.notnull()
# Out:
#     name  college  branch   cgpa  package
# 0   True     True    True   True     True
# 1   True     True    True   True     True
# 2   True     True    True   True     True
# 3  False    False   False  False    False
# 4   True    False    True   True     True
# 5  False     True    True   True     True
# 6   True     True    True   True     True
# 7  False    False    True   True     True
# 8   True    False    True   True    False
# 9  False     True   False  False    False

# %%
#dropna(series+ dataframe) -> how parameter -> works like or
students['name'].dropna() #on series
# Out:
# 0        nitish
# 1         ankit
# 2        rupesh
# 4    mrityunjay
# 6       rishabh
# 8        aditya
# Name: name, dtype: object

# %%
#on dataframe
students.dropna() #drop whole row if it contain a single missing value by default
#this behavior can be override using how parameter in dropna function
# Out:
#       name college branch  cgpa  package
# 0   nitish     bit    eee  6.66      4.0
# 1    ankit     iit     it  8.25      5.0
# 2   rupesh     vit    cse  6.41      6.0
# 6  rishabh    ssit    civ  7.40      8.0

# %%
students.dropna(how = 'all') #removes when all col in a row contain null values
# Out:
#          name college branch   cgpa  package
# 0      nitish     bit    eee   6.66      4.0
# 1       ankit     iit     it   8.25      5.0
# 2      rupesh     vit    cse   6.41      6.0
# 4  mrityunjay     NaN     me   5.60      6.0
# 5         NaN    vlsi     ce   9.00      7.0
# 6     rishabh    ssit    civ   7.40      8.0
# 7         NaN     NaN    cse  10.00      9.0
# 8      aditya     NaN    bio   7.40      NaN
# 9         NaN     git    NaN    NaN      NaN

# %%
# que remove nan value only from name col
students.dropna(subset=['name'])
# Out:
#          name college branch  cgpa  package
# 0      nitish     bit    eee  6.66      4.0
# 1       ankit     iit     it  8.25      5.0
# 2      rupesh     vit    cse  6.41      6.0
# 4  mrityunjay     NaN     me  5.60      6.0
# 6     rishabh    ssit    civ  7.40      8.0
# 8      aditya     NaN    bio  7.40      NaN

# %%
students.dropna(subset=['name' , 'college']) #nan containing both name and college
# Out:
#       name college branch  cgpa  package
# 0   nitish     bit    eee  6.66      4.0
# 1    ankit     iit     it  8.25      5.0
# 2   rupesh     vit    cse  6.41      6.0
# 6  rishabh    ssit    civ  7.40      8.0

# %%
#fillna(series + dataframe) , fills the data inplace of missing values
#on series
students['name'].fillna('unknown')
# Out:
# 0        nitish
# 1         ankit
# 2        rupesh
# 3       unknown
# 4    mrityunjay
# 5       unknown
# 6       rishabh
# 7       unknown
# 8        aditya
# 9       unknown
# Name: name, dtype: object

# %%
#in dataframe
students.fillna(0)
# Out:
#          name college branch   cgpa  package
# 0      nitish     bit    eee   6.66      4.0
# 1       ankit     iit     it   8.25      5.0
# 2      rupesh     vit    cse   6.41      6.0
# 3           0       0      0   0.00      0.0
# 4  mrityunjay       0     me   5.60      6.0
# 5           0    vlsi     ce   9.00      7.0
# 6     rishabh    ssit    civ   7.40      8.0
# 7           0       0    cse  10.00      9.0
# 8      aditya       0    bio   7.40      0.0
# 9           0     git      0   0.00      0.0

# %%
#forward fill and backward fill
students['name'].fillna(method='ffill')
#similary bfill
# Out:
# /tmp/ipython-input-2306875571.py:2: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   students['name'].fillna(method='ffill')
# 0        nitish
# 1         ankit
# 2        rupesh
# 3        rupesh
# 4    mrityunjay
# 5    mrityunjay
# 6       rishabh
# 7       rishabh
# 8        aditya
# 9        aditya
# Name: name, dtype: object

# %%
#drop_duplicates(series+dataframe) -> works like and -> duplicated()
temp = pd.Series([1,1,2,3,3,4,4,4,5,5,5,6])
temp.drop_duplicates() #applying on series
# Out:
# 0     1
# 2     2
# 3     3
# 5     4
# 8     5
# 11    6
# dtype: int64

# %%
#on dataframe
marks.drop_duplicates(keep='first') #by default first to keep the first occurance of the duplicated values
# Out:
#     iq  marks  package
# 0  100     80       10
# 1   90     70        7
# 2  120    100       14
# 3   80     60       23

# %%
marks.drop_duplicates(keep='last') #to keep the last occurance
# Out:
#     iq  marks  package
# 0  100     80       10
# 1   90     70        7
# 2  120    100       14
# 4   80     60       23

# %%
#find the last match played by virat kohli in delhi
ipl['all_players'] = ipl['Team1Players'] + ipl['Team2Players']
ipl.head(1)
# Out:
#         ID       City        Date Season MatchNumber             Team1  \
# 0  1312200  Ahmedabad  2022-05-29   2022       Final  Rajasthan Royals
#
#             Team2                             Venue        TossWinner  \
# 0  Gujarat Titans  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals
#
#   TossDecision  ...     WinningTeam    WonBy Margin  method Player_of_Match  \
# 0          bat  ...  Gujarat Titans  Wickets    7.0     NaN       HH Pandya
#
#                                         Team1Players  \
# 0  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
#
#                                         Team2Players      Umpire1  \
# 0  ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...  CB Gaffaney
#
#        Umpire2                                        all_players
# 0  Nitin Menon  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
#
# [1 rows x 21 columns]

# %%
def did_kohli_play(players_list):
  return 'V Kohli' in players_list

# %%
ipl['did_kohli_play']=ipl['all_players'].apply(did_kohli_play)
ipl[(ipl['City'] == 'Delhi') & (ipl['did_kohli_play']==True)].drop_duplicates(subset=['City','did_kohli_play'],keep='first')
# Out:
#           ID   City        Date Season MatchNumber           Team1  \
# 208  1178421  Delhi  2019-04-28   2019          46  Delhi Capitals
#
#                            Team2                 Venue      TossWinner  \
# 208  Royal Challengers Bangalore  Arun Jaitley Stadium  Delhi Capitals
#
#     TossDecision  ... Margin method Player_of_Match  \
# 208          bat  ...   16.0    NaN        S Dhawan
#
#                                           Team1Players  \
# 208  ['PP Shaw', 'S Dhawan', 'SS Iyer', 'RR Pant', ...
#
#                                           Team2Players       Umpire1  \
# 208  ['PA Patel', 'V Kohli', 'AB de Villiers', 'S D...  BNJ Oxenford
#
#                    Umpire2                                        all_players  \
# 208  KN Ananthapadmanabhan  ['PP Shaw', 'S Dhawan', 'SS Iyer', 'RR Pant', ...
#
#     False did_kohli_play
# 208  True           True
#
# [1 rows x 23 columns]

# %%
#drop(series + dataframe)
temp = pd.Series([10,2,42,44,22,5,25,76])
temp
# Out:
# 0    10
# 1     2
# 2    42
# 3    44
# 4    22
# 5     5
# 6    25
# 7    76
# dtype: int64

# %%
temp.drop(index=[0,6])
# Out:
# 1     2
# 2    42
# 3    44
# 4    22
# 5     5
# 7    76
# dtype: int64

# %%
#drop on dataframe
#students.drop(columns=['branch' , 'cgpa'] , inplace = True)
students.reset_index()
# Out:
#    index        name college  package
# 0      0      nitish     bit      4.0
# 1      1       ankit     iit      5.0
# 2      2      rupesh     vit      6.0
# 3      3         NaN     NaN      NaN
# 4      4  mrityunjay     NaN      6.0
# 5      5         NaN    vlsi      7.0
# 6      6     rishabh    ssit      8.0
# 7      7         NaN     NaN      9.0
# 8      8      aditya     NaN      NaN
# 9      9         NaN     git      NaN

# %%
students.set_index('name').drop(['nitish' , 'aditya'])
# Out:
#            college  package
# name
# ankit          iit      5.0
# rupesh         vit      6.0
# NaN            NaN      NaN
# mrityunjay     NaN      6.0
# NaN           vlsi      7.0
# rishabh       ssit      8.0
# NaN            NaN      9.0
# NaN            git      NaN

# %%
#apply(series + dataframe)
#on series
temp = pd.Series([10,20,30,40,50])

temp
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
#calculate the sigmoid of each value
def sigmoid(value):
  return 1/1+np.exp(-value)

# %%
temp.apply(sigmoid) # in series col wise traversal
# Out:
# 0    1.000045
# 1    1.000000
# 2    1.000000
# 3    1.000000
# 4    1.000000
# dtype: float64

# %%
#on dataframe
points_df = pd.DataFrame(
    {
        '1st point':[(3,4),(-6,5),(0,0),(-10,1),(4,5)],
        '2nd point':[(-3,4),(0,0),(2,2),(10,10),(1,1)]
    }
)

points_df
# Out:
#   1st point 2nd point
# 0    (3, 4)   (-3, 4)
# 1   (-6, 5)    (0, 0)
# 2    (0, 0)    (2, 2)
# 3  (-10, 1)  (10, 10)
# 4    (4, 5)    (1, 1)

# %%
#calculate the euclidian distance
def euclidean(row):
  pt_A = row['1st point']
  pt_B = row['2nd point']

  return ((pt_A[0] - pt_B[0])**2 + (pt_A[1] - pt_B[1])**2)**0.5

# %%
points_df['distance']=points_df.apply(euclidean,axis=1) #row wise calculation in dataframe
points_df
# Out:
#   1st point 2nd point   distance
# 0    (3, 4)   (-3, 4)   6.000000
# 1   (-6, 5)    (0, 0)   7.810250
# 2    (0, 0)    (2, 2)   2.828427
# 3  (-10, 1)  (10, 10)  21.931712
# 4    (4, 5)    (1, 1)   5.000000
